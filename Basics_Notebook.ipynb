# %%
print("hello")
# Out:
# hello

# %%
print("welcome world")
# Out:
# welcome world

# %%
a =12
a2 =12
res =a+a2
print(res)
# Out:
# 24

# %%
a=12
b=2
res=a/b
print(res)
# Out:
# 6.0

# %%
a=15
b=20
c=30
d=2
res=a+b-c*d
print(res)
# Out:
# -25

# %%
a=10
b=12
res=a-b
print(res)
# Out:
# -2

# %%
a=55

# %%
type(a)
# Out:
# int

# %%
A= 'india'

# %%
type(A)
# Out:
# str

# %%
A = "455"

# %%
type(A)
# Out:
# str

# %%
H=20+2j

# %%
type(H)
# Out:
# complex

# %%
a=.7

# %%
type(a)
# Out:
# float

# %%
a=0.7

# %%
type(a)
# Out:
# float

# %%
a=30
b=50
c=60
d=80
res= a+b+c-d

# %%
#print=(res)

# %%
res
# Out:
# 60

# %%
a=30
b=50
c=60
d=80
res= a+b+c-d
#print=(res)

# %%
res
# Out:
# 60

# %%
x=10
y=20
z=50
res=x+y-z
print(res)
# Out:
# -20

# %%
res
# Out:
# -20

# %%
a=10                   #(a**2-b**2)=(a+b)*(a-b)
b=50
y=a**2-b**2
z=(a+b)*(a-b)

print(y==z)           == intragative (true\false)
# Out:
# True

# %%
a=50
b=2
print (a+b)
print (a-b)
print (a*b)
print (a/b)
print (a//b)
print (a%b)
print (a**b)
# Out:
# 52
# 48
# 100
# 25.0
# 25
# 0
# 2500

# %%
False and False                         #And *
# Out:
# False

# %%
False and true
# Out:
# False

# %%
False or False                       #or +
# Out:
# False

# %%
False or True
# Out:
# True

# %%
x=int(input ("enter x value:"))
y=int(input ("enter y value:"))
z=int(input ("enter z value:"))
s=(3*x**2)+(2*y)+z
print(s)
# Out:
# enter x value:6
# enter y value:9
# enter z value:8
# 134

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
cos_name = str(input ("costomer name:"))
cos_ph = str(input ("costomer ph:"))
Idly=10
Dosa=20
Vada=7.50
No_of_Idly = int(input ("No of Idly:"))
No_of_Dosa = int(input ("No of Dosa:"))
No_of_vada = int(input ("No of Vada:"))
Total_Idly_cost = No_of_Idly*Idly
Total_Dosa_cost = No_of_Dosa*Dosa
Total_Vada_cost = No_of_vada*Vada
Total=Total_Dosa_cost+Total_Idly_cost+Total_Vada_cost
print(Total)
# Out:
# costomer name:yuvaraj
# costomer ph:9444881016
# No of Idly:6
# No of Dosa:8
# No of Vada:4
# 250.0

# %%
Student_Name=str(input("Student Name:"))
Student_Mobile_No=str(input("Student Mobile No:"))
Student_Father_Name=str(input("Student Father Name:"))
Student_Mother_Name=str(input("Student Mother Name:"))
Student_Parent_No=str(input("Student Parent No:"))
Student_ID_No=str(input("Student ID No:"))
Student_Address=str(input("Student Address:"))
Student_Email=str(input("Student Email:"))
# Out:
# Student Name:Yuvaraj L
# Student Mobile No:9444881016
# Student Father Name:Lakshmipathy D
# Student Mother Name:Pramila L
# Student Parent No:9444408031
# Student ID No:12345
# Student Address:Arakkonam, Ranipet, Tamilnadu - 631003
# Student Email:yuvarajlakshmpathy105@gmail.com

# %%
a=5
b=10
(a+b)**2==a**2+b**2+2*a*b
# Out:
# True

# %%
a=100.98

# %%
bool (a)
# Out:
# True
