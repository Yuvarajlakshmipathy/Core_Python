# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuvarajlakshmipathy/Core_Python/blob/main/numpy_b4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
# array = collection of related items
# technical array = collection of similar data types  e.g a = [8,9,5,4] ,[6.8,9.0,7.9]
#conceptual array = collection related data items e.g fruits = ['orange','potato','grapes'] its not an conceptual array  e.g = [2121423432,'name',7652347.532, 'chennai']

# %%
s = [6,7,8,'dgd']
type(s)
s_arr = np.array(s)
type(s_arr)
# Out:
# numpy.ndarray

# %%
b = np.array([7,6,'jhgj'])

# %%
type(b)
# Out:
# numpy.ndarray

# %%
c = np.array({6:'jgj',9:'khkj'})
type(c)
# Out:
# numpy.ndarray

# %%
# dimension

c.ndim
# Out:
# 0

# %%
1d = np.array([5,7,3,2])
# Out:
#   File "<ipython-input-13-e6ae490226cc>", line 1
#     1d = np.array([5,7,3,2])
#     ^
# SyntaxError: invalid decimal literal

# %%
d1 = np.array([5,7,3,2]) # 1d array  scalar or one dimensional array

# %%
d1.data

# %%
d2 = np.array([[5,7,3,2],[5,6,4,3]]) # 2d array or vector

# %%
d2.ndim
# Out:
# 2

# %%
d3 = np.array([[[5,7,3,2],[5,6,4,3],[8,6,7,8]],[[15,7,30,2],[5,56,41,3],[6,4,4,3]],[[15,7,30,2],[5,56,41,3],[6,4,4,3]]]) # 3 dimensional array or matrix

# %%
d3.ndim
# Out:
# 3

# %%
k = np.array([8,3,5,6],ndmin = 3)
k.ndim
# Out:
# 3

# %%
def add (a,b):
  res = a+b
  print(res)

# %%
add(90,7)
# Out:
# 97

# %%
add(8,5)
# Out:
# 13

# %%
d = np.array([5,7,3,2])
e = np.array([5,7,3,2])

# %%
print(d+e)
# Out:
# [10 14  6  4]

# %%
print(d-e)
# Out:
# [0 0 0 0]
