# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuvarajlakshmipathy/Core_Python/blob/main/Matplotlib_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Matplotlib : Matplotlib is a popular Python library used for creating visualizations such as charts, plots, histograms, and more. It provides a simple interface for generating high-quality plots.

# %% [markdown]
# Import python libraies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
np.random.seed(10)
df = pd.DataFrame(np.random.rand(1000,1), index = pd.date_range("10-07-2000" , periods=1000),columns=["data"])

# %%
df
# Out:
#                 data
# 2000-10-07  0.771321
# 2000-10-08  0.020752
# 2000-10-09  0.633648
# 2000-10-10  0.748804
# 2000-10-11  0.498507
# ...              ...
# 2003-06-29  0.515589
# 2003-06-30  0.210153
# 2003-07-01  0.165113
# 2003-07-02  0.689948
# 2003-07-03  0.095189
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.data.cumsum().plot()
# Out:
# <Axes: >

# %%
df.data.cumsum()
# Out:
# 2000-10-07      0.771321
# 2000-10-08      0.792073
# 2000-10-09      1.425721
# 2000-10-10      2.174525
# 2000-10-11      2.673032
#                  ...
# 2003-06-29    490.844819
# 2003-06-30    491.054973
# 2003-07-01    491.220085
# 2003-07-02    491.910033
# 2003-07-03    492.005222
# Freq: D, Name: data, Length: 1000, dtype: float64

# %%
df
# Out:
#                 data
# 2000-10-07  0.771321
# 2000-10-08  0.020752
# 2000-10-09  0.633648
# 2000-10-10  0.748804
# 2000-10-11  0.498507
# ...              ...
# 2003-06-29  0.515589
# 2003-06-30  0.210153
# 2003-07-01  0.165113
# 2003-07-02  0.689948
# 2003-07-03  0.095189
#
# [1000 rows x 1 columns]

# %%
df['data1'] = df.data.cumsum()
df['data2'] = df['data'].apply(lambda x : x *3)

# %%
df
# Out:
#                 data       data1     data2
# 2000-10-07  0.771321    0.771321  2.313962
# 2000-10-08  0.020752    0.792073  0.062256
# 2000-10-09  0.633648    1.425721  1.900945
# 2000-10-10  0.748804    2.174525  2.246412
# 2000-10-11  0.498507    2.673032  1.495521
# ...              ...         ...       ...
# 2003-06-29  0.515589  490.844819  1.546766
# 2003-06-30  0.210153  491.054973  0.630460
# 2003-07-01  0.165113  491.220085  0.495338
# 2003-07-02  0.689948  491.910033  2.069844
# 2003-07-03  0.095189  492.005222  0.285568
#
# [1000 rows x 3 columns]

# %%
df.plot(figsize=(20,15))
# Out:
# <Axes: >

# %%
df1 = sbn.load_dataset("iris")

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot(figsize= (15,15))
# Out:
# <Axes: >

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
a = df1.plot(figsize= (10,10),title= ("Iris_DataSet"))
a.set_xlabel("X_Axis")
a.set_ylabel("Y_Axis")
# Out:
# Text(0, 0.5, 'Y_Axis')

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.iloc[0][0:4].plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df1.iloc[0][0:4]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
df2 = sbn.load_dataset("titanic")

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2["pclass"].plot(figsize= (15,15), kind= "bar")
# Out:
# <Axes: >

# %%
df3 = pd.DataFrame(np.random.rand(20,10),columns= ["a","b","c","d","e","f","g","h","i","j"])

# %%
df3
# Out:
#            a         b         c         d         e         f         g  \
# 0   0.931527  0.287686  0.741442  0.406221  0.255709  0.640460  0.037274
# 1   0.276407  0.990669  0.809775  0.005625  0.751421  0.770488  0.404908
# 2   0.063954  0.836221  0.116036  0.708130  0.455278  0.937168  0.482037
# 3   0.636268  0.870612  0.373858  0.038553  0.250771  0.870002  0.641209
# 4   0.297157  0.045924  0.974717  0.190064  0.208686  0.560513  0.339804
# 5   0.847119  0.438051  0.864621  0.648793  0.693744  0.967947  0.243403
# 6   0.404421  0.125233  0.837216  0.165631  0.620266  0.524214  0.358018
# 7   0.770784  0.250914  0.879969  0.285638  0.697387  0.574506  0.390468
# 8   0.820968  0.312970  0.281913  0.183393  0.846573  0.973052  0.210922
# 9   0.487798  0.307023  0.846274  0.292091  0.322640  0.624131  0.301486
# 10  0.513468  0.769252  0.200694  0.508136  0.882500  0.491173  0.954123
# 11  0.607295  0.515360  0.758773  0.234961  0.777144  0.770617  0.435848
# ...

# %%
df3.plot.bar(figsize= (15,15))
# Out:
# <Axes: >

# %%
df3.plot.barh(figsize= (15,15))
# Out:
# <Axes: >

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df1.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['sepal_length'].plot.hist(figsize= (20,20))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(kind = 'hist' , stacked = True , bins = 100 , figsize = (10,10) , title = "histogram of iris")
# Out:
# <Axes: title={'center': 'histogram of iris'}, ylabel='Frequency'>

# %%
df1.plot(kind = 'hist' , stacked = True , bins = 100 , figsize = (10,10) , title = "histogram of iris", orientation = "horizontal")
# Out:
# <Axes: title={'center': 'histogram of iris'}, xlabel='Frequency'>

# %%
df1.hist(figsize= (10,10) , color = 'r' , alpha  = .9)
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df1.plot.scatter(x = "sepal_length" , y = "petal_length" )
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
df1.plot.scatter(x = "sepal_width" , y = "petal_width" )
# Out:
# <Axes: xlabel='sepal_width', ylabel='petal_width'>

# %%
df1.plot.scatter(x = 'sepal_length' , y = 'petal_width', c = 'petal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
df1.plot.scatter(x  ='sepal_length' , y  = 'sepal_width', label = 'sudh' ,s = 180 ,c = 'petal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
df
# Out:
#                 data       data1     data2
# 2000-10-07  0.771321    0.771321  2.313962
# 2000-10-08  0.020752    0.792073  0.062256
# 2000-10-09  0.633648    1.425721  1.900945
# 2000-10-10  0.748804    2.174525  2.246412
# 2000-10-11  0.498507    2.673032  1.495521
# ...              ...         ...       ...
# 2003-06-29  0.515589  490.844819  1.546766
# 2003-06-30  0.210153  491.054973  0.630460
# 2003-07-01  0.165113  491.220085  0.495338
# 2003-07-02  0.689948  491.910033  2.069844
# 2003-07-03  0.095189  492.005222  0.285568
#
# [1000 rows x 3 columns]

# %%
d = df.iloc[0]

# %%
d
# Out:
# data     0.771321
# data1    0.771321
# data2    2.313962
# Name: 2000-10-07 00:00:00, dtype: float64

# %%
d.plot.pie(figsize= (15,15))
# Out:
# <Axes: ylabel='2000-10-07 00:00:00'>

# %%
iris = df1.head(3).T

# %%
iris.iloc[0:4].plot.pie(subplots = True , figsize = (20,20) ,fontsize = 20 , autopct = '%.2f')
# Out:
# array([<Axes: ylabel='0'>, <Axes: ylabel='1'>, <Axes: ylabel='2'>],
#       dtype=object)

# %%
iris.iloc[0:4]
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
pd.plotting.scatter_matrix(df1 , figsize = (20,20),diagonal='kde')
# Out:
# array([[<Axes: xlabel='sepal_length', ylabel='sepal_length'>,
#         <Axes: xlabel='sepal_width', ylabel='sepal_length'>,
#         <Axes: xlabel='petal_length', ylabel='sepal_length'>,
#         <Axes: xlabel='petal_width', ylabel='sepal_length'>],
#        [<Axes: xlabel='sepal_length', ylabel='sepal_width'>,
#         <Axes: xlabel='sepal_width', ylabel='sepal_width'>,
#         <Axes: xlabel='petal_length', ylabel='sepal_width'>,
#         <Axes: xlabel='petal_width', ylabel='sepal_width'>],
#        [<Axes: xlabel='sepal_length', ylabel='petal_length'>,
#         <Axes: xlabel='sepal_width', ylabel='petal_length'>,
#         <Axes: xlabel='petal_length', ylabel='petal_length'>,
#         <Axes: xlabel='petal_width', ylabel='petal_length'>],
#        [<Axes: xlabel='sepal_length', ylabel='petal_width'>,
#         <Axes: xlabel='sepal_width', ylabel='petal_width'>,
#         <Axes: xlabel='petal_length', ylabel='petal_width'>,
# ...

# %%
df['data'].plot(style = 'r*' , legend = True , label = "sudh" )
# Out:
# <Axes: >

# %%
# !pip install plotly
# !pip install cufflinks
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 9.5 MB/s eta 0:00:00
# ...

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf

# %%
py.__version__
# Out:
# '5.15.0'

# %%
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1.iplot()
# Out:
# <div>                            <div id="e9d53780-ad10-464d-ad64-b75b10f3686f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
